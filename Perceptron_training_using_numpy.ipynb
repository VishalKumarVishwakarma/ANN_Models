# %% [markdown]
# ### Objective - Here I will make a binary classifier using Perceptron Trick Classifier

# %%
# Importing Libraries
from sklearn.datasets import make_classification  
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generating dataset which is linearly separable

# %%
from sklearn.datasets import make_classification
X, y = make_classification(
    n_samples = 100,
    n_features = 2,
    n_informative = 1,
    n_redundant =0,
    n_classes = 2,
    n_clusters_per_class = 1,
    random_state = 47,
    hypercube =False,
    class_sep = 10
)

# %% [markdown]
# ### Visualizing Dataset

# %%
plt.figure(figsize = (10,6))
plt.scatter(X[:,0],X[:,1],c = y,cmap = 'winter',s = 100)

# %%
X[0:5,:]
# Out:
# array([[ 0.80767365,  7.2597327 ],
#        [ 0.43292671,  6.39284678],
#        [-0.34372243,  7.56465572],
#        [ 0.57282781, -1.51361356],
#        [ 0.2651835 , -0.80969959]])

# %%
y[0:5]
# Out:
# array([1, 1, 1, 0, 0])

# %% [markdown]
# ### Making Model

# %%
def step(z):
    return 1 if z >=0 else 0

# %%
def perceptron(X,y):
    X = np.insert(X,0,1,axis = 1)
    weights = np.zeros(X.shape[1])
    lr= 0.1
    
    for i in range(10000):
        j = np.random.randint(0,100)
        y_hat = step(np.dot(X[j],weights))
        weights = weights + lr*(y[j] - y_hat)*X[j]
        
    return weights[0],weights[1:]

# %% [markdown]
# ### Training Model

# %%
intercept_,coef_ = perceptron(X,y)

# %%
print('intercept is :',intercept_)
print('Coefficient is :',coef_)
# Out:
# intercept is : -0.6
# Coefficient is : [0.04566855 0.20164665]

# %%
slope = -1*coef_[0]/coef_[1]
c = -1*intercept_/coef_[1]

# %% [markdown]
# ### Evaluation

# %%
x_input = np.linspace(-3,3,100)
y_input = slope*x_input + c

# %%
plt.figure(figsize = (10,6))
plt.plot(x_input,y_input)
plt.scatter(X[:,0],X[:,1],c = y,cmap = 'winter',s = 100)
